# %%
# !pip install numpy
# !pip install soundfile
# !pip install jams
# !pip install librosa
# Out:
# Requirement already satisfied: numpy in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (2.3.5)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: soundfile in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (0.13.1)
# Requirement already satisfied: cffi>=1.0 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from soundfile) (2.0.0)
# Requirement already satisfied: numpy in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from soundfile) (2.3.5)
# Requirement already satisfied: pycparser in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from cffi>=1.0->soundfile) (2.23)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: jams in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (0.3.5)
# Requirement already satisfied: numpy>=1.20.0 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from jams) (2.3.5)
# Requirement already satisfied: jsonschema>=4.0.1 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from jams) (4.25.1)
# Requirement already satisfied: pandas>=1.2.0 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from jams) (2.3.3)
# Requirement already satisfied: mir_eval>=0.8.2 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from jams) (0.8.2)
# Requirement already satisfied: sortedcontainers>=2.1.0 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from jams) (2.4.0)
# Requirement already satisfied: six in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from jams) (1.17.0)
# Requirement already satisfied: decorator in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from jams) (5.2.1)
# Requirement already satisfied: attrs>=22.2.0 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from jsonschema>=4.0.1->jams) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from jsonschema>=4.0.1->jams) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from jsonschema>=4.0.1->jams) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from jsonschema>=4.0.1->jams) (0.29.0)
# Requirement already satisfied: scipy>=1.4.0 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from mir_eval>=0.8.2->jams) (1.16.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from pandas>=1.2.0->jams) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from pandas>=1.2.0->jams) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from pandas>=1.2.0->jams) (2025.2)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Collecting librosa
#   Using cached librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Using cached audioread-3.1.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting numba>=0.51.0 (from librosa)
#   Using cached numba-0.62.1-cp313-cp313-macosx_12_0_arm64.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy>=1.22.3 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from librosa) (2.3.5)
# Requirement already satisfied: scipy>=1.6.0 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from librosa) (1.16.3)
# Collecting scikit-learn>=1.1.0 (from librosa)
#   Using cached scikit_learn-1.7.2-cp313-cp313-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting joblib>=1.0 (from librosa)
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: decorator>=4.3.0 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from librosa) (5.2.1)
# Requirement already satisfied: soundfile>=0.12.1 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from librosa) (0.13.1)
# Collecting pooch>=1.1 (from librosa)
#   Using cached pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Using cached soxr-1.0.0-cp312-abi3-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Collecting typing_extensions>=4.1.1 (from librosa)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting lazy_loader>=0.1 (from librosa)
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa)
#   Using cached msgpack-1.1.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Collecting standard-aifc (from librosa)
#   Using cached standard_aifc-3.13.0-py3-none-any.whl.metadata (969 bytes)
# Collecting standard-sunau (from librosa)
#   Using cached standard_sunau-3.13.0-py3-none-any.whl.metadata (914 bytes)
# Requirement already satisfied: packaging in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from lazy_loader>=0.1->librosa) (25.0)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba>=0.51.0->librosa)
#   Using cached llvmlite-0.45.1-cp313-cp313-macosx_12_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from pooch>=1.1->librosa) (4.5.0)
# Collecting requests>=2.19.0 (from pooch>=1.1->librosa)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn>=1.1.0->librosa)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: cffi>=1.0 in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Collecting standard-chunk (from standard-aifc->librosa)
#   Using cached standard_chunk-3.13.0-py3-none-any.whl.metadata (860 bytes)
# Collecting audioop-lts (from standard-aifc->librosa)
#   Using cached audioop_lts-0.2.2-cp313-abi3-macosx_11_0_arm64.whl.metadata (2.0 kB)
# Requirement already satisfied: pycparser in /Users/bm343/Documents/guitar-ml/venv/lib/python3.13/site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.23)
# Collecting charset_normalizer<4,>=2 (from requests>=2.19.0->pooch>=1.1->librosa)
#   Using cached charset_normalizer-3.4.4-cp313-cp313-macosx_10_13_universal2.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests>=2.19.0->pooch>=1.1->librosa)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.19.0->pooch>=1.1->librosa)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.19.0->pooch>=1.1->librosa)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Using cached librosa-0.11.0-py3-none-any.whl (260 kB)
# Using cached audioread-3.1.0-py3-none-any.whl (23 kB)
# Using cached joblib-1.5.2-py3-none-any.whl (308 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# Using cached msgpack-1.1.2-cp313-cp313-macosx_11_0_arm64.whl (84 kB)
# Using cached numba-0.62.1-cp313-cp313-macosx_12_0_arm64.whl (2.7 MB)
# Using cached pooch-1.8.2-py3-none-any.whl (64 kB)
# Using cached scikit_learn-1.7.2-cp313-cp313-macosx_12_0_arm64.whl (8.6 MB)
# Using cached soxr-1.0.0-cp312-abi3-macosx_11_0_arm64.whl (163 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached standard_aifc-3.13.0-py3-none-any.whl (10 kB)
# Using cached standard_sunau-3.13.0-py3-none-any.whl (7.4 kB)
# Using cached llvmlite-0.45.1-cp313-cp313-macosx_12_0_arm64.whl (37.3 MB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Using cached audioop_lts-0.2.2-cp313-abi3-macosx_11_0_arm64.whl (26 kB)
# Using cached standard_chunk-3.13.0-py3-none-any.whl (4.9 kB)
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Using cached charset_normalizer-3.4.4-cp313-cp313-macosx_10_13_universal2.whl (208 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Installing collected packages: standard-chunk, urllib3, typing_extensions, threadpoolctl, soxr, msgpack, llvmlite, lazy_loader, joblib, idna, charset_normalizer, certifi, audioop-lts, standard-sunau, standard-aifc, scikit-learn, requests, numba, pooch, audioread, librosa
# Successfully installed audioop-lts-0.2.2 audioread-3.1.0 certifi-2025.11.12 charset_normalizer-3.4.4 idna-3.11 joblib-1.5.2 lazy_loader-0.4 librosa-0.11.0 llvmlite-0.45.1 msgpack-1.1.2 numba-0.62.1 pooch-1.8.2 requests-2.32.5 scikit-learn-1.7.2 soxr-1.0.0 standard-aifc-3.13.0 standard-chunk-3.13.0 standard-sunau-3.13.0 threadpoolctl-3.6.0 typing_extensions-4.15.0 urllib3-2.5.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import random
from pathlib import Path
import numpy as np
import soundfile as sf
import jams
import librosa

# %%
# Setting up paths
cdw = Path.cwd()
root = cdw.parents[0]
audio_dir = root / "dataset" / "audio"
jams_dir = root / "dataset" / "annotation"
output_dir = root / "processed_data"
output_dir.mkdir(exist_ok=True, parents=True)
wav_files = sorted(list(audio_dir.glob("*.wav"))) # Gets all .wav files in this directory
if not wav_files:
    print("No wav files found. Need to create audio directory with wave files")
random.seed(42)
random.shuffle(wav_files)

# %%
STRING_INFO = [
    ("E2", 40), ("A2", 45), ("D3", 50), ("G3", 55), ("B3", 59), ("E4", 64),
]
HOP_LENGTH = 512
WINDOW_SIZE = 128
SR = 44100
N_FFT=2048
STRIDE = 128

# %%
# Splitting into train/test
split_idx = int(len(wav_files) * 0.8)
train_files = wav_files[:split_idx]
test_files = wav_files[split_idx:]
print(f"Total Songs: {len(wav_files)}")
print(f"Train: {len(train_files)} | Test: {len(test_files)}")
# Out:
# Total Songs: 357
# Train: 285 | Test: 72

# %%
def extract_guitar_tabs_from_jam(jam):
    note_anns = jam.search(namespace="note_midi") # We only need this node for guitars
    events = []

    for string_idx, (ann, (string_name, open_midi)) in enumerate(zip(note_anns, STRING_INFO), start=1):
        # String matched up to list just by order of string. Base string is 1 is E2
        for obs in ann:
            midi = float(obs.value)
            midi_rounded = round(midi)
            fret = midi_rounded - open_midi # This gives us the fret value. open_midi is derived from string info

            # Skip negative frets (errors in annotation)
            if fret < 0: continue

            events.append({
                "start": obs.time,
                "end": obs.time + obs.duration,
                "string_index": string_idx,
                "fret": int(fret),
            })
    # Sort chronologically
    events.sort(key=lambda e: e["start"]) # Sorting by start time (multiple strings can be played at once)
    return events

def create_label_matrix(events, total_frames, sr, hop_length):
    # 21 represents Silence / No Note
    y = np.full((6, total_frames), 21, dtype=int)

    for event in events:
        # JAMS uses 1-6 for strings, we need 0-5 for array indexing
        string_idx = event["string_index"] - 1 
        fret = event["fret"]
        
        # Convert Seconds -> Frames
        start_frame = librosa.time_to_frames(event["start"], sr=sr, hop_length=hop_length)
        end_frame = librosa.time_to_frames(event["end"], sr=sr, hop_length=hop_length)

        # Bounds check
        start_frame = max(0, start_frame)
        end_frame = min(total_frames, end_frame)

        if start_frame < end_frame:
            y[string_idx, start_frame:end_frame] = fret
    return y

def process_track(audio_path, jams_path):
    audio, sr = sf.read(str(audio_path)) # Reading the sound file. Again this is the .wav file so we are going to get a bunch of data points
    # audio.shape -> # datapoints, 6 (6 strings/channels)
    # print(audio.shape)
    if audio.ndim > 1 and audio.shape[0] > audio.shape[1]:
        audio = audio.T # Librosa expects strings, samples not samples, strings that sf.read gives
    # audio data obtained
    
    jam = jams.load(str(jams_path))
    # Need to get labels (string data) derived from jam file
    events = extract_guitar_tabs_from_jam(jam)
    return audio, sr, events

def slice_data(features, labels, window_size, stride):
    X_chunks = []
    y_chunks = []
    
    total_frames = features.shape[2]
    
    for t in range(0, total_frames - window_size, stride):
        # Slice X: (6 strings, 128 freqs, window_time)
        x_slice = features[:, :, t : t + window_size]
        
        # Slice y: (6 strings, window_time)
        y_slice = labels[:, t : t + window_size]
        
        X_chunks.append(x_slice)
        y_chunks.append(y_slice)
        
    return X_chunks, y_chunks

# %%
# Creating loop to process datasets
def build_dataset(file_list):
    X = []
    y = []

    for i, wav_file in enumerate(file_list):
        jams_name = wav_file.stem.split("_hex_cln")[0] + ".jams" # Naming convention for files is different
        matching_jams_path = jams_dir / jams_name
        if not matching_jams_path.exists():
            continue # Continue if for some reason there is no corresponding jam file
        # Our goal is to get the raw data for the audio

    return np.array(X), np.array(y)

# %%
def build_dataset(file_list):
  X_master, y_master = [], []
  for i, wav_file in enumerate(file_list):
    jams_name = wav_file.stem.split("_hex_cln")[0] + ".jams" # Naming convention for files is different
    matching_jams_path = jams_dir / jams_name
    audio, sr, events = process_track(wav_file, matching_jams_path)
    # We now have events (which is going to become our y values) we need to make X and y values offically now.
    # We are going to do this by taking the signal data and converting it into spectogram data raw audio -> spectogram
    spect = librosa.feature.melspectrogram(y=audio, sr=SR, n_fft=N_FFT, hop_length = HOP_LENGTH) # n_fft is length of FFT window, hop length is how far window moves onward
    # # Computing mel spectrograms
    spect = librosa.power_to_db(spect, ref=np.max) # ref = np.max sets baseline (zero) to loudest sound. Everything else is negative
    # Mel spectograms will be our data points now need labels
    # print(spect.shape)  # (6, 128, 2827) strings, window, # frames
    num_time_frames = spect.shape[2]
    labels = create_label_matrix(events, num_time_frames, SR, HOP_LENGTH) # Created labels
    X_c, y_c = slice_data(spect, labels, WINDOW_SIZE, STRIDE) # Want to break up songs into smaller chunks
    X_master.extend(X_c)
    y_master.extend(y_c)
    if i % 10 == 0:
      print(f"  Processed {i}/{len(file_list)}...")
  return np.array(X_master), np.array(y_master)

# %%
# Build datasets
print("\n--- Building Training Set ---")
X_train, y_train = build_dataset(train_files)

print("\n--- Building Testing Set ---")
X_test, y_test = build_dataset(test_files)

# 5. Final Output Stats
print("\n--- DONE ---")
print(f"X_train shape: {X_train.shape}") # Expect (N_samples, 6, 128, 128)
print(f"y_train shape: {y_train.shape}") # Expect (N_samples, 6, 128)

# 6. Save to disk
save_path = output_dir / "guitar_hex_data.npz"
np.savez(save_path, X_train=X_train, y_train=y_train, X_test=X_test, y_test=y_test)
print(f"Saved dataset to {save_path}")
# Out:
# --- Building Training Set ---
#   Processed 0/285...
#   Processed 10/285...
#   Processed 20/285...
#   Processed 30/285...
#   Processed 40/285...
#   Processed 50/285...
#   Processed 60/285...
#   Processed 70/285...
#   Processed 80/285...
#   Processed 90/285...
#   Processed 100/285...
#   Processed 110/285...
#   Processed 120/285...
#   Processed 130/285...
#   Processed 140/285...
#   Processed 150/285...
#   Processed 160/285...
#   Processed 170/285...
#   Processed 180/285...
#   Processed 190/285...
#   Processed 200/285...
#   Processed 210/285...
#   Processed 220/285...
#   Processed 230/285...
#   Processed 240/285...
#   Processed 250/285...
#   Processed 260/285...
#   Processed 270/285...
#   Processed 280/285...
#
# --- Building Testing Set ---
#   Processed 0/72...
#   Processed 10/72...
#   Processed 20/72...
#   Processed 30/72...
#   Processed 40/72...
#   Processed 50/72...
#   Processed 60/72...
#   Processed 70/72...
#
# --- DONE ---
# X_train shape: (5601, 6, 128, 128)
# y_train shape: (5601, 6, 128)
# Saved dataset to /Users/bm343/Documents/guitar-ml/processed_data/guitar_hex_data.npz
